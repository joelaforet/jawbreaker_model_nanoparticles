# %%
import numpy as np
import pandas as pd

import os

# %%
os.getcwd()
# Out:
# '/hpc/group/rekerlab/jrl78/CoAggregators/simulations'

# %%
os.chdir('MachineLearning')

# %%
os.getcwd()
# Out:
# '/hpc/group/rekerlab/jrl78/CoAggregators/simulations/MachineLearning'

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/DanReker/CoAggregators/master/data/simulation_results.tsv', sep = '\t')
df2.head()
# Out:
#         drug      excipient  contact_av      LF_KE        LF_PE   AvDist_1  \
# 0  Sorafenib       caffeine      0.0900  21.403186 -1844.636682  25.875372
# 1  Sorafenib  succinic_acid      0.0115  13.200327 -1212.499051  38.677273
# 2  Sorafenib  octyl_gallate      3.5410  21.672408  -523.673001   0.363870
# 3  Sorafenib  DL-malic_acid      0.0140  13.047957 -1113.666669  21.656012
# 4  Sorafenib    adipic_acid      0.0705  20.041669 -1103.938549  24.440334
#
#     AvDist_2   AvDist_3   AvDist_4  d(distance)_max_1  ...  d(distance)_max_3  \
# 0  25.880890  27.536453  27.545477        1961.285824  ...        1272.815968
# 1  38.694542  39.296300  39.309353        3475.989202  ...        2110.688832
# 2   0.377605   0.378072   0.408919         384.765377  ...         768.209409
# 3  21.684135  24.991657  25.026085        2113.359999  ...        1884.913643
# 4  24.442545  33.161163  33.181103        2913.664509  ...        1615.682808
#
# ...

# %%
df2.columns
# Out:
# Index(['drug', 'excipient', 'contact_av', 'LF_KE', 'LF_PE', 'AvDist_1',
#        'AvDist_2', 'AvDist_3', 'AvDist_4', 'd(distance)_max_1',
#        'd(distance)_max_2', 'd(distance)_max_3', 'd(distance)_max_4',
#        'd(distance)_avg_1', 'd(distance)_avg_2', 'd(distance)_avg_3',
#        'd(distance)_avg_4', 'Variance_1', 'Variance_2', 'Variance_3',
#        'Variance_4', 'CLASS'],
#       dtype='object')

# %% [markdown]
# # Max Velocity

# %%
df2.boxplot(column = 'd(distance)_max_1', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'d(distance)_max_1'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'd(distance)_max_2', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'d(distance)_max_2'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'd(distance)_max_3', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'d(distance)_max_3'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'd(distance)_max_4', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'d(distance)_max_4'}, xlabel='CLASS'>

# %% [markdown]
# # Average Velocity

# %%
df2.boxplot(column = 'd(distance)_avg_1', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'d(distance)_avg_1'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'd(distance)_avg_2', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'d(distance)_avg_2'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'd(distance)_avg_3', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'d(distance)_avg_3'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'd(distance)_avg_4', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'d(distance)_avg_4'}, xlabel='CLASS'>

# %% [markdown]
# # Average Distance

# %%
df2.boxplot(column = 'AvDist_1', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'AvDist_1'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'AvDist_2', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'AvDist_2'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'AvDist_3', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'AvDist_3'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'AvDist_4', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'AvDist_4'}, xlabel='CLASS'>

# %% [markdown]
# # Potential/Kinetic Energy

# %%
df2.boxplot(column = 'LF_PE', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'LF_PE'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'LF_KE', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'LF_KE'}, xlabel='CLASS'>

# %% [markdown]
# # Variance

# %%
df2.boxplot(column = 'Variance_1', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'Variance_1'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'Variance_2', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'Variance_2'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'Variance_3', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'Variance_3'}, xlabel='CLASS'>

# %%
df2.boxplot(column = 'Variance_4', by = 'CLASS')
# Out:
# <AxesSubplot:title={'center':'Variance_4'}, xlabel='CLASS'>

# %% [markdown]
# # Calculating Statistics

# %%
from scipy import stats

# %%
x = df2['d(distance)_max_3']

# %%
k2, p = stats.normaltest(x)

# %%
df2.columns[2:-2, ]
# Out:
# Index(['contact_av', 'LF_KE', 'LF_PE', 'AvDist_1', 'AvDist_2', 'AvDist_3',
#        'AvDist_4', 'd(distance)_max_1', 'd(distance)_max_2',
#        'd(distance)_max_3', 'd(distance)_max_4', 'd(distance)_avg_1',
#        'd(distance)_avg_2', 'd(distance)_avg_3', 'd(distance)_avg_4',
#        'Variance_1', 'Variance_2', 'Variance_3'],
#       dtype='object')

# %%
x =  [x for x in df2.columns[2:-1]]

for i in x:
    #print(i)
    k2, p = stats.normaltest(df2[i])

    alpha = 0.05
    print("p = {:g}".format(p))

    if p < alpha: # null hypothesis: x comes from a normal distribution
        print("The null hypothesis can be rejected for {}".format(i))
    else:
         print("The null hypothesis cannot be rejected for {}".format(i))
# Out:
# p = 0
# The null hypothesis can be rejected for contact_av
# p = 4.63156e-41
# The null hypothesis can be rejected for LF_KE
# p = 3.91462e-59
# The null hypothesis can be rejected for LF_PE
# p = 3.0971e-30
# The null hypothesis can be rejected for AvDist_1
# p = 2.38113e-29
# The null hypothesis can be rejected for AvDist_2
# p = 1.18945e-44
# The null hypothesis can be rejected for AvDist_3
# p = 4.20801e-43
# The null hypothesis can be rejected for AvDist_4
# p = 1.22788e-20
# The null hypothesis can be rejected for d(distance)_max_1
# p = 8.64368e-09
# The null hypothesis can be rejected for d(distance)_max_2
# p = 0.0537567
# The null hypothesis cannot be rejected for d(distance)_max_3
# p = 3.36651e-05
# The null hypothesis can be rejected for d(distance)_max_4
# p = 3.00401e-33
# The null hypothesis can be rejected for d(distance)_avg_1
# p = 1.22093e-31
# The null hypothesis can be rejected for d(distance)_avg_2
# p = 1.361e-20
# ...

# %%
from scipy.stats import ranksums

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
feature_names = df2.columns[2:-1]
df_long = pd.melt(df2, 'CLASS', var_name='Feature', value_name='Value') 

all_t = list()
all_p = list()
for case in range(len(feature_names)):
    sub_df = df_long[df_long.Feature == feature_names[case]]
    g1 = sub_df[sub_df['CLASS'] == 0]['Value'].values
    g2 = sub_df[sub_df['CLASS'] == 1]['Value'].values
    t, p = stats.ttest_ind(g1, g2)
    all_t.append(t)
    all_p.append(p)
    
    t, p = stats.ttest_ind(g1, g2)
    
#print(all_t)
#print(all_p)
print(feature_names)
print(np.count_nonzero(np.array(feature_names)[np.array(all_p) < 0.05]))
# Out:
# Index(['contact_av', 'LF_KE', 'LF_PE', 'AvDist_1', 'AvDist_2', 'AvDist_3',
#        'AvDist_4', 'd(distance)_max_1', 'd(distance)_max_2',
#        'd(distance)_max_3', 'd(distance)_max_4', 'd(distance)_avg_1',
#        'd(distance)_avg_2', 'd(distance)_avg_3', 'd(distance)_avg_4',
#        'Variance_1', 'Variance_2', 'Variance_3', 'Variance_4'],
#       dtype='object')
# 18

# %%
# renaming so that class 0 will appear as setosa and class 1 as versicolor
df_long.loc[df_long.CLASS==0, 'CLASS'] = 'Negative'
df_long.loc[df_long.CLASS==1, 'CLASS'] = 'Positive'
# Boxplots
fig, axes = plt.subplots(2,2, figsize=(20,10), dpi=300)
axes = axes.flatten()
for idx, feature in enumerate(feature_names):
    ax = sns.boxplot(x='Feature', hue='CLASS', y='Value', data = df_long[df_long.Feature == feature], linewidth=2, showmeans=True, meanprops={'marker':'*','markerfacecolor':'white', 'markeredgecolor':'black'}, ax=axes[idx])
    #* tick params
    axes[idx].set_xticklabels([str(feature)], rotation=0)
    axes[idx].set(xlabel=None)
    axes[idx].set(ylabel=None)
    axes[idx].grid(alpha=0.5)
    axes[idx].legend(loc='lower right', prop={'size': 11})
 
    #*set edge color = black
    for b in range(len(ax.artists)):
        ax.artists[b].set_edgecolor('black')
        ax.artists[b].set_alpha(0.8)
   
    #* statistical tests
    x1, x2 = -0.20, 0.20
    y, h, col = df_long[df_long.Feature == feature]['Value'].max()+1, 2, 'k'
    axes[idx].plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    axes[idx].text((x1+x2)*.5, y+h, 'statistically significant', ha='center', va='bottom', color=col)
fig.suptitle("Significant feature differences between positive and negative nanoparticle samples", size=14, y=0.93)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-f7991f51ece1> in <module>
#       6 axes = axes.flatten()
#       7 for idx, feature in enumerate(feature_names):
# ----> 8     ax = sns.boxplot(x='Feature', hue='CLASS', y='Value', data = df_long[df_long.Feature == feature], linewidth=2, showmeans=True, meanprops={'marker':'*','markerfacecolor':'white', 'markeredgecolor':'black'}, ax=axes[idx])
#       9     #* tick params
#      10     axes[idx].set_xticklabels([str(feature)], rotation=0)
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
from statannotations.Annotator import Annotator

# %%
df2.head()
# Out:
#         drug      excipient  contact_av      LF_KE        LF_PE   AvDist_1  \
# 0  Sorafenib       caffeine      0.0900  21.403186 -1844.636682  25.875372
# 1  Sorafenib  succinic_acid      0.0115  13.200327 -1212.499051  38.677273
# 2  Sorafenib  octyl_gallate      3.5410  21.672408  -523.673001   0.363870
# 3  Sorafenib  DL-malic_acid      0.0140  13.047957 -1113.666669  21.656012
# 4  Sorafenib    adipic_acid      0.0705  20.041669 -1103.938549  24.440334
#
#     AvDist_2   AvDist_3   AvDist_4  d(distance)_max_1  ...  d(distance)_avg_1  \
# 0  25.880890  27.536453  27.545477        1961.285824  ...          38.477194
# 1  38.694542  39.296300  39.309353        3475.989202  ...          48.905099
# 2   0.377605   0.378072   0.408919         384.765377  ...          -0.738829
# 3  21.684135  24.991657  25.026085        2113.359999  ...          49.025977
# 4  24.442545  33.161163  33.181103        2913.664509  ...          69.020004
#
# ...

# %%
tempdf = df2[['contact_av', 'CLASS']]
tempdf.head()
# Out:
#    contact_av  CLASS
# 0      0.0900      0
# 1      0.0115      0
# 2      3.5410      0
# 3      0.0140      0
# 4      0.0705      0

# %%
df2.columns
# Out:
# Index(['drug', 'excipient', 'contact_av', 'LF_KE', 'LF_PE', 'AvDist_1',
#        'AvDist_2', 'AvDist_3', 'AvDist_4', 'd(distance)_max_1',
#        'd(distance)_max_2', 'd(distance)_max_3', 'd(distance)_max_4',
#        'd(distance)_avg_1', 'd(distance)_avg_2', 'd(distance)_avg_3',
#        'd(distance)_avg_4', 'Variance_1', 'Variance_2', 'Variance_3',
#        'Variance_4', 'CLASS', 'labels'],
#       dtype='object')

# %%
sns.boxplot(x = 'CLASS', y = 'contact_av', data= df2)
# Out:
# <AxesSubplot:xlabel='CLASS', ylabel='contact_av'>

# %%
sns.boxplot(x = 'CLASS', y = 'LF_KE', data= df2)
# Out:
# <AxesSubplot:xlabel='CLASS', ylabel='LF_KE'>

# %%
sns.boxplot(x = 'CLASS', y = 'LF_PE', data= df2)
# Out:
# <AxesSubplot:xlabel='CLASS', ylabel='LF_PE'>

# %%
sns.boxplot(x = 'CLASS', y = 'AvDist_1', data= df2)
# Out:
# <AxesSubplot:xlabel='CLASS', ylabel='AvDist_1'>

# %%
sns.boxplot(x = 'CLASS', y = 'AvDist_2', data= df2)
# Out:
# <AxesSubplot:xlabel='CLASS', ylabel='AvDist_2'>

# %%
sns.boxplot(x = 'CLASS', y = 'AvDist_3', data= df2)
# Out:
# <AxesSubplot:xlabel='CLASS', ylabel='AvDist_3'>

# %%
sns.boxplot(x = 'CLASS', y = 'AvDist_4', data= df2)
# Out:
# <AxesSubplot:xlabel='CLASS', ylabel='AvDist_4'>

# %%
ax = sns.boxplot(x = 'CLASS', y = 'AvDist_4', data= df2)

# %%
import statannotations

# %%
df2.head()
# Out:
#         drug      excipient  contact_av      LF_KE        LF_PE   AvDist_1  \
# 0  Sorafenib       caffeine      0.0900  21.403186 -1844.636682  25.875372
# 1  Sorafenib  succinic_acid      0.0115  13.200327 -1212.499051  38.677273
# 2  Sorafenib  octyl_gallate      3.5410  21.672408  -523.673001   0.363870
# 3  Sorafenib  DL-malic_acid      0.0140  13.047957 -1113.666669  21.656012
# 4  Sorafenib    adipic_acid      0.0705  20.041669 -1103.938549  24.440334
#
#     AvDist_2   AvDist_3   AvDist_4  d(distance)_max_1  ...  d(distance)_avg_1  \
# 0  25.880890  27.536453  27.545477        1961.285824  ...          38.477194
# 1  38.694542  39.296300  39.309353        3475.989202  ...          48.905099
# 2   0.377605   0.378072   0.408919         384.765377  ...          -0.738829
# 3  21.684135  24.991657  25.026085        2113.359999  ...          49.025977
# 4  24.442545  33.161163  33.181103        2913.664509  ...          69.020004
#
# ...

# %%
def convert(x):
    if x == 0:
        return 'Negative'
    else:
        return 'Positive'

# %%
df2['labels'] = df2.apply(lambda row: convert(row['CLASS']), axis = 1)
df2.head()
# Out:
#         drug      excipient  contact_av      LF_KE        LF_PE   AvDist_1  \
# 0  Sorafenib       caffeine      0.0900  21.403186 -1844.636682  25.875372
# 1  Sorafenib  succinic_acid      0.0115  13.200327 -1212.499051  38.677273
# 2  Sorafenib  octyl_gallate      3.5410  21.672408  -523.673001   0.363870
# 3  Sorafenib  DL-malic_acid      0.0140  13.047957 -1113.666669  21.656012
# 4  Sorafenib    adipic_acid      0.0705  20.041669 -1103.938549  24.440334
#
#     AvDist_2   AvDist_3   AvDist_4  d(distance)_max_1  ...  d(distance)_avg_1  \
# 0  25.880890  27.536453  27.545477        1961.285824  ...          38.477194
# 1  38.694542  39.296300  39.309353        3475.989202  ...          48.905099
# 2   0.377605   0.378072   0.408919         384.765377  ...          -0.738829
# 3  21.684135  24.991657  25.026085        2113.359999  ...          49.025977
# 4  24.442545  33.161163  33.181103        2913.664509  ...          69.020004
#
# ...

# %%
df2.columns
# Out:
# Index(['drug', 'excipient', 'contact_av', 'LF_KE', 'LF_PE', 'AvDist_1',
#        'AvDist_2', 'AvDist_3', 'AvDist_4', 'd(distance)_max_1',
#        'd(distance)_max_2', 'd(distance)_max_3', 'd(distance)_max_4',
#        'd(distance)_avg_1', 'd(distance)_avg_2', 'd(distance)_avg_3',
#        'd(distance)_avg_4', 'Variance_1', 'Variance_2', 'Variance_3',
#        'Variance_4', 'CLASS', 'labels'],
#       dtype='object')

# %% [markdown]
# # Average Contacts

# %%
x = "labels"
y = 'contact_av'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:8.173e-11 U_stat=3.794e+04
# (<AxesSubplot:xlabel='labels', ylabel='contact_av'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c981b3dd0>])

# %% [markdown]
# # Energy Plots

# %%
x = "labels"
y = 'LF_KE'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:9.889e-10 U_stat=3.944e+04
# (<AxesSubplot:xlabel='labels', ylabel='LF_KE'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c982155d0>])

# %%
x = "labels"
y = 'LF_PE'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:4.680e-01 U_stat=6.043e+04
# (<AxesSubplot:xlabel='labels', ylabel='LF_PE'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c981b3910>])

# %% [markdown]
# # Average Distance Plots

# %%
x = "labels"
y = 'AvDist_1'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:1.164e-10 U_stat=8.838e+04
# (<AxesSubplot:xlabel='labels', ylabel='AvDist_1'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c980d7c50>])

# %%
x = "labels"
y = 'AvDist_2'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:2.695e-10 U_stat=8.788e+04
# (<AxesSubplot:xlabel='labels', ylabel='AvDist_2'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c980baf10>])

# %%
x = "labels"
y = 'AvDist_3'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:2.013e-09 U_stat=8.664e+04
# (<AxesSubplot:xlabel='labels', ylabel='AvDist_3'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c980c7610>])

# %%
x = "labels"
y = 'AvDist_4'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:7.292e-09 U_stat=8.581e+04
# (<AxesSubplot:xlabel='labels', ylabel='AvDist_4'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93e2b710>])

# %% [markdown]
# # Max Velocity Plots

# %%
x = "labels"
y = 'd(distance)_max_1'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:2.557e-07 U_stat=8.335e+04
# (<AxesSubplot:xlabel='labels', ylabel='d(distance)_max_1'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93db7210>])

# %%
x = "labels"
y = 'd(distance)_max_2'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:1.662e-05 U_stat=8.005e+04
# (<AxesSubplot:xlabel='labels', ylabel='d(distance)_max_2'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93cdb890>])

# %%
x = "labels"
y = 'd(distance)_max_3'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:1.959e-04 U_stat=7.778e+04
# (<AxesSubplot:xlabel='labels', ylabel='d(distance)_max_3'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93cdba50>])

# %%
x = "labels"
y = 'd(distance)_max_4'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:8.800e-05 U_stat=7.855e+04
# (<AxesSubplot:xlabel='labels', ylabel='d(distance)_max_4'>,
#  [<statannotations.Annotation.Annotation at 0x7f6ca030a850>])

# %% [markdown]
# # Average Velocity

# %%
x = "labels"
y = 'd(distance)_avg_1'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:1.934e-07 U_stat=8.355e+04
# (<AxesSubplot:xlabel='labels', ylabel='d(distance)_avg_1'>,
#  [<statannotations.Annotation.Annotation at 0x7f6ca02f2610>])

# %%
x = "labels"
y = 'd(distance)_avg_2'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:3.928e-09 U_stat=8.621e+04
# (<AxesSubplot:xlabel='labels', ylabel='d(distance)_avg_2'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93b21a50>])

# %%
x = "labels"
y = 'd(distance)_avg_3'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:3.067e-06 U_stat=8.145e+04
# (<AxesSubplot:xlabel='labels', ylabel='d(distance)_avg_3'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93ba4490>])

# %%
x = "labels"
y = 'd(distance)_avg_4'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:2.210e-06 U_stat=8.171e+04
# (<AxesSubplot:xlabel='labels', ylabel='d(distance)_avg_4'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93afbbd0>])

# %%
df2.columns
# Out:
# Index(['drug', 'excipient', 'contact_av', 'LF_KE', 'LF_PE', 'AvDist_1',
#        'AvDist_2', 'AvDist_3', 'AvDist_4', 'd(distance)_max_1',
#        'd(distance)_max_2', 'd(distance)_max_3', 'd(distance)_max_4',
#        'd(distance)_avg_1', 'd(distance)_avg_2', 'd(distance)_avg_3',
#        'd(distance)_avg_4', 'Variance_1', 'Variance_2', 'Variance_3',
#        'Variance_4', 'CLASS', 'labels'],
#       dtype='object')

# %% [markdown]
# # Variance

# %%
x = "labels"
y = 'Variance_1'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:7.362e-10 U_stat=8.727e+04
# (<AxesSubplot:xlabel='labels', ylabel='Variance_1'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93956210>])

# %%
x = "labels"
y = 'Variance_2'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:5.850e-09 U_stat=8.595e+04
# (<AxesSubplot:xlabel='labels', ylabel='Variance_2'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93899f50>])

# %%
x = "labels"
y = 'Variance_3'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:2.932e-07 U_stat=8.325e+04
# (<AxesSubplot:xlabel='labels', ylabel='Variance_3'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c938140d0>])

# %%
x = "labels"
y = 'Variance_4'
order = ['Negative', 'Positive']

ax = sns.boxplot(data=df2, x=x, y=y, order=order)

pairs=[('Negative', 'Positive')]

annotator = Annotator(ax, pairs, data=df2, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Negative vs. Positive: Mann-Whitney-Wilcoxon test two-sided, P_val:2.676e-06 U_stat=8.156e+04
# (<AxesSubplot:xlabel='labels', ylabel='Variance_4'>,
#  [<statannotations.Annotation.Annotation at 0x7f6c93791150>])
