# %% [markdown]
# # Import Statements

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# # I have a lot of simulations that I need to render and sort into either the 1/0 folder based on their class

# %%
def cleanNames(col):
    col = col.capitalize()    
    split = col.split('_')
    for a in range(len(split)):
        split[a] = split[a].capitalize()
    return ''.join(split)

# %%
os.getcwd()
# Out:
# '/hpc/group/rekerlab/jrl78/CoAggregators/simulations'

# %%
data = pd.read_csv("FULL_screening_data.tsv",delimiter = '\t')

# %%
data
# Out:
#             DRUG              EXCIPIENT  CLASS  SIZE_REDUCTION  RADIUS
# 0      Sorafenib               caffeine      0             NaN     NaN
# 1      Sorafenib          succinic_acid      0             NaN     NaN
# 2      Sorafenib          octyl_gallate      0             NaN     NaN
# 3      Sorafenib          DL-malic_acid      0             NaN     NaN
# 4      Sorafenib            adipic_acid      0             NaN     NaN
# ...          ...                    ...    ...             ...     ...
# 1435  Pranlukast            risperidone      0             NaN     NaN
# 1436  Pranlukast            fluconazole      0             NaN     NaN
# 1437  Pranlukast   methotrexate_hydrate      0             NaN     NaN
# 1438  Pranlukast  tenofovir_alafenamide      0             NaN     NaN
# 1439  Pranlukast          carbamazepine      0             NaN     NaN
#
# [1440 rows x 5 columns]

# %%
data['EXCIPIENT'] = data['EXCIPIENT'].apply(cleanNames)

# %%
cleanDF = pd.DataFrame(data = [data['DRUG'], data['EXCIPIENT'] , data['CLASS']]).T

# %%
cleanDF
# Out:
#             DRUG             EXCIPIENT CLASS
# 0      Sorafenib              Caffeine     0
# 1      Sorafenib          SuccinicAcid     0
# 2      Sorafenib          OctylGallate     0
# 3      Sorafenib          Dl-malicAcid     0
# 4      Sorafenib            AdipicAcid     0
# ...          ...                   ...   ...
# 1435  Pranlukast           Risperidone     0
# 1436  Pranlukast           Fluconazole     0
# 1437  Pranlukast   MethotrexateHydrate     0
# 1438  Pranlukast  TenofovirAlafenamide     0
# 1439  Pranlukast         Carbamazepine     0
#
# [1440 rows x 3 columns]

# %%
cleanDF['FileTag'] = cleanDF['DRUG'] + '_' + cleanDF['EXCIPIENT'] + '_12_4'

# %%
cleanDF.head(25)
# Out:
#          DRUG                 EXCIPIENT CLASS  \
# 0   Sorafenib                  Caffeine     0
# 1   Sorafenib              SuccinicAcid     0
# 2   Sorafenib              OctylGallate     0
# 3   Sorafenib              Dl-malicAcid     0
# 4   Sorafenib                AdipicAcid     0
# 5   Sorafenib       Triazabicyclodecene     0
# 6   Sorafenib                       Dbu     0
# 7   Sorafenib              L-asparagine     0
# 8   Sorafenib               Theobromine     0
# 9   Sorafenib  3,3'-thiodipropionicAcid     0
# 10  Sorafenib              Theophylline     0
# 11  Sorafenib                   Borneol     0
# 12  Sorafenib            Cinnamaldehyde     0
# 13  Sorafenib                 Aspartame     0
# 14  Sorafenib                  Squalene     0
# 15  Sorafenib              Benzaldehyde     0
# 16  Sorafenib        SodiumDeoxycholate     1
# 17  Sorafenib                CholicAcid     1
# 18  Sorafenib           GlycocholicAcid     1
# ...

# %%
fileClasses = pd.DataFrame(data = [cleanDF['FileTag'], cleanDF['CLASS']]).T

# %%
fileClasses
# Out:
#                                    FileTag CLASS
# 0                  Sorafenib_Caffeine_12_4     0
# 1              Sorafenib_SuccinicAcid_12_4     0
# 2              Sorafenib_OctylGallate_12_4     0
# 3              Sorafenib_Dl-malicAcid_12_4     0
# 4                Sorafenib_AdipicAcid_12_4     0
# ...                                    ...   ...
# 1435           Pranlukast_Risperidone_12_4     0
# 1436           Pranlukast_Fluconazole_12_4     0
# 1437   Pranlukast_MethotrexateHydrate_12_4     0
# 1438  Pranlukast_TenofovirAlafenamide_12_4     0
# 1439         Pranlukast_Carbamazepine_12_4     0
#
# [1440 rows x 2 columns]

# %%
import shutil

# %%
os.getcwd()
# Out:
# '/hpc/group/rekerlab/jrl78/CoAggregators/simulations'

# %%
destDir1 = '/hpc/group/rekerlab/jrl78/CoAggregators/simulations/Video Classifier/Images/1'

# %%
def moveFile(fileClass):
    
    fileName = f'openmm_IMPH20_{fileClass[0]}.pdb'
    filepath = os.path.join(os.getcwd(), fileName)
    if os.path.exists(filepath):
        if fileClass[1] == 1:
            destDir1 = f'/hpc/group/rekerlab/jrl78/CoAggregators/simulations/Video Classifier/Images/1/{fileName}'
            shutil.move(filepath, destDir1)

        if fileClass[1] == 0:
            destDir0 = f'/hpc/group/rekerlab/jrl78/CoAggregators/simulations/Video Classifier/Images/0/{fileName}'
            shutil.move(filepath, destDir0)

    
    print("Job's Done!")

# %%
os.getcwd()
# Out:
# '/hpc/group/rekerlab/jrl78/CoAggregators/simulations/ManySims'

# %%
test = ('Sorafenib_CholicAcid_12_4', 1)

# %%
os.chdir('../')

# %%
os.chdir('ManySims')

# %%
moveFile(test)
# Out:
# Job's Done!

# %% [markdown]
# # Function to move files works, now to apply

# %%
fileClasses
# Out:
#                                    FileTag CLASS
# 0                  Sorafenib_Caffeine_12_4     0
# 1              Sorafenib_SuccinicAcid_12_4     0
# 2              Sorafenib_OctylGallate_12_4     0
# 3              Sorafenib_Dl-malicAcid_12_4     0
# 4                Sorafenib_AdipicAcid_12_4     0
# ...                                    ...   ...
# 1435           Pranlukast_Risperidone_12_4     0
# 1436           Pranlukast_Fluconazole_12_4     0
# 1437   Pranlukast_MethotrexateHydrate_12_4     0
# 1438  Pranlukast_TenofovirAlafenamide_12_4     0
# 1439         Pranlukast_Carbamazepine_12_4     0
#
# [1440 rows x 2 columns]

# %%
for row in fileClasses.itertuples():
    temp = (row.FileTag, row.CLASS)
    moveFile(temp)
# Out:
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# Job's Done!
# ...

# %% [markdown]
# # Now to render all of the sims

# %%
a = ["a_b_c_d", "c_D_a_a"]

# %%
b=[]
for x in a:
    b.append(x.split('_')[0]+ '_' + x.split('_')[2])
b
# Out:
# ['a_c', 'c_a']

# %%
print("a")
# Out:
# a
